# %% [markdown]
# <a href="https://colab.research.google.com/github/DioGitH/uts-machine-learning-ti3f/blob/main/UTS_Maulidio_Farhan_Rizkullah_TI3F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Maulidio Farhan Rizkullah
# ### 2141720041
# ### 19
# ### TI-3F

# %% [markdown]
# ## UTS Machine Learning

# %% [markdown]
# Berdasarkan pemaparan kasus, Anda diminta untuk,
#
# 1. Pilih 5 citra plat nomor untuk setiap anggota kelompok dari dataset yang telah disediakan. [DOWNLOAD](https://storage.googleapis.com/kuliah_mah/dummy.zip)
# 2. Lakukan segmentasi pada citra plat nomor untuk memperjelas karakter pada plat nomor.
# 3. Anda dapat menggunakan algortima K-Means seperti yang telah dijelaskan pada praktikum sebelumnya atau menggunakan algoritma klasterisasi yang lain.
# 4. Anda diperkenankan untuk melakukan pra pengolahan data (preprocessing) pada citra seperti,
#     - Merubah color space
#     - Reduksi dimensi
#     - dsb
# 5. Tampilkan perbandingan citra antara sebelum dan sesudah di segmentasi
#
# **Open Challange** (Opsional)
#  - Bagaimana cara melakukan evaluasi pada hasil segementasi?
#  - Terapkan pada kasus ini!
#
#
# **Catatan:**
# 1. Proses loading citra dicontohkan dengan menggunakan library openCV
# 2. Secara default, openCV akan memuat citra dalam format BGR

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from google.colab.patches import cv2_imshow # path cv2.imshow di google colab
from google.colab import drive
from sklearn.cluster import KMeans

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
def plot_pixels(data, title, colors=None, N=10000):
    if colors is None:
        colors = data

    # choose a random subset
    rng = np.random.RandomState(0)
    i = rng.permutation(data.shape[0])[:N]
    colors = colors[i]
    R, G, B = data[i].T

    fig, ax = plt.subplots(1, 2, figsize=(8, 4))
    ax[0].scatter(R, G, color=colors, marker='.')
    ax[0].set(xlabel='Red', ylabel='Green', xlim=(0, 1), ylim=(0, 1))

    ax[1].scatter(R, B, color=colors, marker='.')
    ax[1].set(xlabel='Red', ylabel='Blue', xlim=(0, 1), ylim=(0, 1))

    fig.suptitle(title, size=14)

# %% [markdown]
# #### Plat 1

# %%
# Load Gambar
img = cv2.imread('/content/drive/MyDrive/Images/platUts/plat1.jpg')

# Tampilkan gambar
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1163x321>

# %%
h, w, ch= img.shape
print(h)
print(w)
print(ch)
# Out:
# 321
# 1163
# 3

# %%
data = img / 255.0
data = data.reshape(h * w, ch)
data.shape
# Out:
# (373323, 3)

# %%
plot_pixels(data, title='Input color space: 16 million possible colors')

# %%
kmeans = KMeans(n_clusters=2, random_state=0)
kmeans.fit(data)
centers = kmeans.cluster_centers_
image_kmeans = centers[kmeans.labels_].reshape(img.shape)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 8))

ax[0].imshow(img)
ax[0].set_title('Gambar Asli', size=16)
ax[1].imshow(image_kmeans)
ax[1].set_title('Hasil Segmentasi', size=16)
# Out:
# Text(0.5, 1.0, 'Hasil Segmentasi')

# %% [markdown]
# #### Plat 2

# %%
# Load Gambar
img2 = cv2.imread('/content/drive/MyDrive/Images/platUts/plat2.jpg')

# Tampilkan gambar
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=1271x362>

# %%
h, w, ch= img2.shape
print(h)
print(w)
print(ch)
# Out:
# 362
# 1271
# 3

# %%
data2 = img2 / 255.0
data2 = data2.reshape(h * w, ch)
data2.shape
# Out:
# (460102, 3)

# %%
plot_pixels(data2, title='Input color space: 16 million possible colors')

# %%
kmeans = KMeans(n_clusters=2, random_state=0)
kmeans.fit(data2)
centers = kmeans.cluster_centers_
image_kmeans = centers[kmeans.labels_].reshape(img2.shape)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 8))

ax[0].imshow(cv2.cvtColor(img2, cv2.COLOR_BGR2RGB))
ax[0].set_title('Gambar Asli', size=16)
ax[1].imshow(image_kmeans)
ax[1].set_title('Hasil Segmentasi', size=16)
# Out:
# Text(0.5, 1.0, 'Hasil Segmentasi')

# %% [markdown]
# #### Plat 3

# %%
# Load Gambar
img3 = cv2.imread('/content/drive/MyDrive/Images/platUts/plat3.jpg')

# Tampilkan gambar
cv2_imshow(img3)
# Out:
# <PIL.Image.Image image mode=RGB size=1233x343>

# %%
h, w, ch= img3.shape
print(h)
print(w)
print(ch)
# Out:
# 343
# 1233
# 3

# %%
data3 = img3 / 255.0
data3 = data3.reshape(h * w, ch)
data3.shape
# Out:
# (422919, 3)

# %%
plot_pixels(data3, title='Input color space: 16 million possible colors')

# %%
kmeans = KMeans(n_clusters=2, random_state=0)
kmeans.fit(data3)
centers = kmeans.cluster_centers_
image_kmeans = centers[kmeans.labels_].reshape(img3.shape)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 8))

ax[0].imshow(cv2.cvtColor(img3, cv2.COLOR_BGR2RGB))
ax[0].set_title('Gambar Asli', size=16)
ax[1].imshow(image_kmeans)
ax[1].set_title('Hasil Segmentasi', size=16)
# Out:
# Text(0.5, 1.0, 'Hasil Segmentasi')

# %% [markdown]
# #### Plat 4

# %%
# Load Gambar
img4 = cv2.imread('/content/drive/MyDrive/Images/platUts/plat4.jpg')

# Tampilkan gambar
cv2_imshow(img4)
# Out:
# <PIL.Image.Image image mode=RGB size=652x187>

# %%
h, w, ch= img4.shape
print(h)
print(w)
print(ch)
# Out:
# 187
# 652
# 3

# %%
data4 = img4 / 255.0
data4 = data4.reshape(h * w, ch)
data4.shape
# Out:
# (121924, 3)

# %%
plot_pixels(data4, title='Input color space: 16 million possible colors')

# %%
kmeans = KMeans(n_clusters=2, random_state=0)
kmeans.fit(data4)
centers = kmeans.cluster_centers_
image_kmeans = centers[kmeans.labels_].reshape(img4.shape)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 8))

ax[0].imshow(cv2.cvtColor(img4, cv2.COLOR_BGR2RGB))
ax[0].set_title('Gambar Asli', size=16)
ax[1].imshow(image_kmeans)
ax[1].set_title('Hasil Segmentasi', size=16)
# Out:
# Text(0.5, 1.0, 'Hasil Segmentasi')

# %% [markdown]
# #### Plat 5

# %%
# Load Gambar
img5 = cv2.imread('/content/drive/MyDrive/Images/platUts/plat5.jpg')

# Tampilkan gambar
cv2_imshow(img5)
# Out:
# <PIL.Image.Image image mode=RGB size=976x247>

# %%
h, w, ch= img5.shape
print(h)
print(w)
print(ch)
# Out:
# 247
# 976
# 3

# %%
data5 = img5 / 255.0
data5 = data5.reshape(h * w, ch)
data5.shape
# Out:
# (241072, 3)

# %%
plot_pixels(data5, title='Input color space: 16 million possible colors')

# %%
kmeans = KMeans(n_clusters=2, random_state=0)
kmeans.fit(data5)
centers = kmeans.cluster_centers_
image_kmeans = centers[kmeans.labels_].reshape(img5.shape)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 8))

ax[0].imshow(cv2.cvtColor(img5, cv2.COLOR_BGR2RGB))
ax[0].set_title('Gambar Asli', size=16)
ax[1].imshow(image_kmeans)
ax[1].set_title('Hasil Segmentasi', size=16)
# Out:
# Text(0.5, 1.0, 'Hasil Segmentasi')
